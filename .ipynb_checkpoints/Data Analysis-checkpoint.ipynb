# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## LeNet CNN

# %%
lenet_cpu = pd.read_csv('lenet-mnist/result/cpu/results.txt')
lenet_gpu = pd.read_csv('lenet-mnist/result/gpu/results.txt')
lenet_multigpu = pd.read_csv('lenet-mnist/result/multigpu/results.txt')

# %%
lenet_cpu.head()
# Out:
#    batch_size  epochs      loss  accuracy         time
# 0          64       5  0.087532  0.973667  1291.886047
# 1          64      10  0.049986  0.984606  2572.866152
# 2         128       5  0.143379  0.956930  1249.217450
# 3         128      10  0.081867  0.975373  2496.298805
# 4         256       5  0.221158  0.934712  1122.488445

# %%
def plot_printer(df):
    subdfs = [df.loc[(df.epochs == epoch)] for epoch in df.epochs.unique()]
    for subdf in subdfs:
        plt.plot(subdf.batch_size, subdf.time, label="{} epochs".format(subdf.epochs.unique()[0]))
    plt.xlabel('Batch size')
    plt.ylabel('Time (seconds)')
    plt.legend()
    plt.show()

# %%
plot_printer(lenet_cpu)

# %%
plot_printer(lenet_gpu)

# %%
plot_printer(lenet_multigpu)

# %% [markdown]
# ## IMDB RNN

# %%
rnn_gpu = pd.read_csv('rnn-imdb/result/gpu/results.txt')
rnn_multigpu = pd.read_csv('rnn-imdb/result/multigpu/results.txt')

# %%
rnn_gpu.head()
# Out:
#    batch_size  epochs      loss  accuracy         time
# 0          64       5  0.147828   0.94720   588.848011
# 1          64      10  0.069104   0.97944  1182.875857
# 2         128       5  0.161986   0.94188   336.635153
# 3         128      10  0.085337   0.97364   669.697136
# 4         256       5  0.182243   0.93332   199.555630

# %%
plot_printer(rnn_gpu)

# %%
plot_printer(rnn_multigpu)
